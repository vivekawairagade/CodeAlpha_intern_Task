# %% [markdown]
# task 1

# %% [markdown]
# WEBSITE:- books.toscrape.com

# %% [markdown]
# Install Required Libraries

# %%
# !pip install requests beautifulsoup4 pandas

# %% [markdown]
# Fetch the Web Page

# %%
import requests
from bs4 import BeautifulSoup

url = "https://books.toscrape.com/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# Scrape Data from Multiple Pages

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

titles, prices, availability, ratings = [], [], [], []

# Loop through first 5 pages (you can extend to all 50)
for page in range(1, 6):
    url = f"http://books.toscrape.com/catalogue/page-{page}.html"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    for book in soup.find_all("article", class_="product_pod"):
        titles.append(book.h3.a["title"])
        prices.append(book.find("p", class_="price_color").get_text())
        availability.append(book.find("p", class_="instock availability").get_text().strip())
        ratings.append(book.p["class"][1])

df = pd.DataFrame({
    "Title": titles,
    "Price": prices,
    "Availability": availability,
    "Rating": ratings
})
print(df.head())
# Out:
#                                    Title    Price Availability Rating
# 0                   A Light in the Attic  Â£51.77     In stock  Three
# 1                     Tipping the Velvet  Â£53.74     In stock    One
# 2                             Soumission  Â£50.10     In stock    One
# 3                          Sharp Objects  Â£47.82     In stock   Four
# 4  Sapiens: A Brief History of Humankind  Â£54.23     In stock   Five

# %% [markdown]
# Customize the Dataset
# Convert Price to numeric values.
#
# Map Rating words (One–Five) to numbers (1–5).
#
# Clean Availability text.

# %%
# Clean price string: remove unwanted characters and convert to float
df["Price"] = df["Price"].str.replace("Â", "", regex=False)
df["Price"] = df["Price"].str.replace("£", "", regex=False)
df["Price"] = df["Price"].astype(float)

# %%
df
# Out:
#                                                 Title  Price Availability  \
# 0                                A Light in the Attic  51.77     In stock
# 1                                  Tipping the Velvet  53.74     In stock
# 2                                          Soumission  50.10     In stock
# 3                                       Sharp Objects  47.82     In stock
# 4               Sapiens: A Brief History of Humankind  54.23     In stock
# ..                                                ...    ...          ...
# 95  Lumberjanes Vol. 3: A Terrible Plan (Lumberjan...  19.92     In stock
# 96  Layered: Baking, Building, and Styling Spectac...  40.11     In stock
# 97  Judo: Seven Steps to Black Belt (an Introducto...  53.90     In stock
# 98                                               Join  35.67     In stock
# 99          In the Country We Love: My Family Divided  22.00     In stock
#
#    Rating
# 0   Three
# 1     One
# 2     One
# 3    Four
# 4    Five
# ...

# %% [markdown]
# Save  Custom Dataset

# %%
df.to_csv("custom_books_dataset.csv", index=False)

# %%
df
# Out:
#                                                 Title  Price Availability  \
# 0                                A Light in the Attic  51.77     In stock
# 1                                  Tipping the Velvet  53.74     In stock
# 2                                          Soumission  50.10     In stock
# 3                                       Sharp Objects  47.82     In stock
# 4               Sapiens: A Brief History of Humankind  54.23     In stock
# ..                                                ...    ...          ...
# 95  Lumberjanes Vol. 3: A Terrible Plan (Lumberjan...  19.92     In stock
# 96  Layered: Baking, Building, and Styling Spectac...  40.11     In stock
# 97  Judo: Seven Steps to Black Belt (an Introducto...  53.90     In stock
# 98                                               Join  35.67     In stock
# 99          In the Country We Love: My Family Divided  22.00     In stock
#
#    Rating
# 0   Three
# 1     One
# 2     One
# 3    Four
# 4    Five
# ...

# %% [markdown]
# Prices are numeric, enabling statistical analysis and visualizations.
#
# Ratings are converted to numbers (1–5), making sentiment or quality analysis possible.
#
# Availability is standardized, allowing stock trend analysis.
